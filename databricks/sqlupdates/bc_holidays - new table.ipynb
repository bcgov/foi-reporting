# %%
# %sql

CREATE TABLE IF NOT EXISTS default.bc_holidays (
  holiday_date DATE,
  holiday_name STRING
)
USING DELTA
LOCATION '/mnt/delta/tables/bc_holidays';

# %%
# %sql

INSERT INTO default.bc_holidays VALUES
-- 2019
(DATE '2019-01-01', 'New Year''s Day'),
(DATE '2019-02-18', 'Family Day'),
(DATE '2019-04-19', 'Good Friday'),
(DATE '2019-05-20', 'Victoria Day'),
(DATE '2019-07-01', 'Canada Day'),
(DATE '2019-08-05', 'B.C. Day'),
(DATE '2019-09-02', 'Labour Day'),
(DATE '2019-09-30', 'National Day for Truth and Reconciliation'), -- Became a statutory holiday in 2021
(DATE '2019-10-14', 'Thanksgiving Day'),
(DATE '2019-11-11', 'Remembrance Day'),
(DATE '2019-12-25', 'Christmas Day'),
(DATE '2019-12-26', 'Boxing Day'),

-- 2020
(DATE '2020-01-01', 'New Year''s Day'),
(DATE '2020-02-17', 'Family Day'),
(DATE '2020-04-10', 'Good Friday'),
(DATE '2020-05-18', 'Victoria Day'),
(DATE '2020-07-01', 'Canada Day'),
(DATE '2020-08-03', 'B.C. Day'),
(DATE '2020-09-07', 'Labour Day'),
(DATE '2020-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2020-10-12', 'Thanksgiving Day'),
(DATE '2020-11-11', 'Remembrance Day'),
(DATE '2020-12-25', 'Christmas Day'),
(DATE '2020-12-26', 'Boxing Day'),

-- 2021
(DATE '2021-01-01', 'New Year''s Day'),
(DATE '2021-02-15', 'Family Day'),
(DATE '2021-04-02', 'Good Friday'),
(DATE '2021-05-24', 'Victoria Day'),
(DATE '2021-07-01', 'Canada Day'),
(DATE '2021-08-02', 'B.C. Day'),
(DATE '2021-09-06', 'Labour Day'),
(DATE '2021-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2021-10-11', 'Thanksgiving Day'),
(DATE '2021-11-11', 'Remembrance Day'),
(DATE '2021-12-25', 'Christmas Day'),
(DATE '2021-12-26', 'Boxing Day'),

-- 2022
(DATE '2022-01-01', 'New Year''s Day'),
(DATE '2022-02-21', 'Family Day'),
(DATE '2022-04-15', 'Good Friday'),
(DATE '2022-05-23', 'Victoria Day'),
(DATE '2022-07-01', 'Canada Day'),
(DATE '2022-08-01', 'B.C. Day'),
(DATE '2022-09-05', 'Labour Day'),
(DATE '2022-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2022-10-10', 'Thanksgiving Day'),
(DATE '2022-11-11', 'Remembrance Day'),
(DATE '2022-12-25', 'Christmas Day'),
(DATE '2022-12-26', 'Boxing Day'),

-- 2023
(DATE '2023-01-01', 'New Year''s Day'),
(DATE '2023-02-20', 'Family Day'),
(DATE '2023-04-07', 'Good Friday'),
(DATE '2023-05-22', 'Victoria Day'),
(DATE '2023-07-01', 'Canada Day'),
(DATE '2023-08-07', 'B.C. Day'),
(DATE '2023-09-04', 'Labour Day'),
(DATE '2023-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2023-10-09', 'Thanksgiving Day'),
(DATE '2023-11-11', 'Remembrance Day'),
(DATE '2023-12-25', 'Christmas Day'),
(DATE '2023-12-26', 'Boxing Day'),

-- 2024
(DATE '2024-01-01', 'New Year''s Day'),
(DATE '2024-02-19', 'Family Day'),
(DATE '2024-03-29', 'Good Friday'),
(DATE '2024-05-20', 'Victoria Day'),
(DATE '2024-07-01', 'Canada Day'),
(DATE '2024-08-05', 'B.C. Day'),
(DATE '2024-09-02', 'Labour Day'),
(DATE '2024-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2024-10-14', 'Thanksgiving Day'),
(DATE '2024-11-11', 'Remembrance Day'),
(DATE '2024-12-25', 'Christmas Day'),
(DATE '2024-12-26', 'Boxing Day'),

-- 2025
(DATE '2025-01-01', 'New Year''s Day'),
(DATE '2025-02-17', 'Family Day'),
(DATE '2025-04-18', 'Good Friday'),
(DATE '2025-05-19', 'Victoria Day'),
(DATE '2025-07-01', 'Canada Day'),
(DATE '2025-08-04', 'B.C. Day'),
(DATE '2025-09-01', 'Labour Day'),
(DATE '2025-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2025-10-13', 'Thanksgiving Day'),
(DATE '2025-11-11', 'Remembrance Day'),
(DATE '2025-12-25', 'Christmas Day'),
(DATE '2025-12-26', 'Boxing Day'),

-- 2026
(DATE '2026-01-01', 'New Year''s Day'),
(DATE '2026-02-16', 'Family Day'),
(DATE '2026-04-03', 'Good Friday'),
(DATE '2026-05-18', 'Victoria Day'),
(DATE '2026-07-01', 'Canada Day'),
(DATE '2026-08-03', 'B.C. Day'),
(DATE '2026-09-07', 'Labour Day'),
(DATE '2026-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2026-10-12', 'Thanksgiving Day'),
(DATE '2026-11-11', 'Remembrance Day'),
(DATE '2026-12-25', 'Christmas Day'),
(DATE '2026-12-26', 'Boxing Day'),

-- 2027
(DATE '2027-01-01', 'New Year''s Day'),
(DATE '2027-02-15', 'Family Day'),
(DATE '2027-03-26', 'Good Friday'),
(DATE '2027-05-24', 'Victoria Day'),
(DATE '2027-07-01', 'Canada Day'),
(DATE '2027-08-02', 'B.C. Day'),
(DATE '2027-09-06', 'Labour Day'),
(DATE '2027-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2027-10-11', 'Thanksgiving Day'),
(DATE '2027-11-11', 'Remembrance Day'),
(DATE '2027-12-25', 'Christmas Day'),
(DATE '2027-12-26', 'Boxing Day'),

-- 2028
(DATE '2028-01-01', 'New Year''s Day'),
(DATE '2028-02-21', 'Family Day'),
(DATE '2028-04-14', 'Good Friday'),
(DATE '2028-05-22', 'Victoria Day'),
(DATE '2028-07-01', 'Canada Day'),
(DATE '2028-08-07', 'B.C. Day'),
(DATE '2028-09-04', 'Labour Day'),
(DATE '2028-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2028-10-09', 'Thanksgiving Day'),
(DATE '2028-11-11', 'Remembrance Day'),
(DATE '2028-12-25', 'Christmas Day'),
(DATE '2028-12-26', 'Boxing Day'),

-- 2029
(DATE '2029-01-01', 'New Year''s Day'),
(DATE '2029-02-19', 'Family Day'),
(DATE '2029-03-30', 'Good Friday'),
(DATE '2029-05-21', 'Victoria Day'),
(DATE '2029-07-01', 'Canada Day'),
(DATE '2029-08-06', 'B.C. Day'),
(DATE '2029-09-03', 'Labour Day'),
(DATE '2029-09-30', 'National Day for Truth and Reconciliation'),
(DATE '2029-10-08', 'Thanksgiving Day'),
(DATE '2029-11-11', 'Remembrance Day'),
(DATE '2029-12-25', 'Christmas Day'),
(DATE '2029-12-26', 'Boxing Day');
